# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#print(api_key)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# for i in range(10):
#     print(cities[i])
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up counters and lists
#Each list will contain parsed data from json file for a single column
counter=0
set_counter = 1

city_name = []
cod = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Account for skips - added this towards the end
skip_counter = 0
skip_list = []

# Base url for openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build query URL
for city in cities:
    
    query_url = url + "appid=" + api_key + "&q=" + city+"&units=metric"
   
    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    # Get the temperature from the response
    #print(f"The weather API responded for {city} at number {counter} with: {weather_json}.")
    
    try:
    #append data for each city to the corresponding list
        city_name.append(weather_json['name'])
        cod.append(weather_json['cod'])
        cloudiness.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        humidity.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
        print("Processing Record " + str(counter)+ " | " + str.title(city))
    except (KeyError, NameError, TypeError, AttributeError):
        print("Processing Record " + str(counter) +  " | " + str.title(city))
        print(f"The requested city of: {str.title(city)} was not found. Skipping...")
        skip_counter += 1
        skip_list.append(city)
        
    counter += 1
    if counter == 51:
        set_counter += 1
        counter = 1
# Out:
# Processing Record 0 | Esperance
# Processing Record 1 | Rikitea
# Processing Record 2 | Dovolnoye
# Processing Record 3 | Muros
# Processing Record 4 | Chagda
# The requested city of: Chagda was not found. Skipping...
# Processing Record 5 | Ribeira Grande
# Processing Record 6 | Upernavik
# Processing Record 7 | Bluff
# Processing Record 8 | Mbandaka
# Processing Record 9 | Nanortalik
# Processing Record 10 | Castro
# Processing Record 11 | Belushya Guba
# The requested city of: Belushya Guba was not found. Skipping...
# Processing Record 12 | Chokurdakh
# Processing Record 13 | Kasangulu
# Processing Record 14 | Mys Shmidta
# The requested city of: Mys Shmidta was not found. Skipping...
# Processing Record 15 | Zhezkazgan
# Processing Record 16 | Cherskiy
# Processing Record 17 | Lavrentiya
# Processing Record 18 | Ushuaia
# Processing Record 19 | Pangody
# Processing Record 20 | Kapaa
# Processing Record 21 | Khatanga
# Processing Record 22 | Albany
# Processing Record 23 | Nalut
# Processing Record 24 | Kaitangata
# Processing Record 25 | Busselton
# Processing Record 26 | Amargosa
# Processing Record 27 | Cockburn Town
# Processing Record 28 | Jamestown
# Processing Record 29 | Kautokeino
# Processing Record 30 | Kurilsk
# Processing Record 31 | Hofn
# Processing Record 32 | Sinnamary
# Processing Record 33 | Phan Rang
# The requested city of: Phan Rang was not found. Skipping...
# Processing Record 34 | Oyek
# Processing Record 35 | Tasiilaq
# Processing Record 36 | Saint-Philippe
# Processing Record 37 | Punta Arenas
# Processing Record 38 | Maniitsoq
# Processing Record 39 | Hobart
# Processing Record 40 | Palafrugell
# Processing Record 41 | Lebu
# Processing Record 42 | Ngukurr
# The requested city of: Ngukurr was not found. Skipping...
# Processing Record 43 | Lalomanu
# The requested city of: Lalomanu was not found. Skipping...
# Processing Record 44 | Cape Town
# Processing Record 45 | Mataura
# Processing Record 46 | Cayenne
# Processing Record 47 | Oistins
# Processing Record 48 | Saskylakh
# Processing Record 49 | Taolanaro
# The requested city of: Taolanaro was not found. Skipping...
# Processing Record 50 | Butaritari
# Processing Record 1 | Vanavara
# Processing Record 2 | Tuktoyaktuk
# Processing Record 3 | Qaanaaq
# Processing Record 4 | Marrakesh
# Processing Record 5 | Sakakah
# The requested city of: Sakakah was not found. Skipping...
# Processing Record 6 | Barabai
# Processing Record 7 | Liverpool
# Processing Record 8 | Atuona
# Processing Record 9 | Eureka
# Processing Record 10 | Ippy
# Processing Record 11 | Thompson
# Processing Record 12 | Port-Gentil
# Processing Record 13 | Challapata
# Processing Record 14 | Caxito
# Processing Record 15 | Terney
# Processing Record 16 | Barrow
# Processing Record 17 | Adrar
# Processing Record 18 | Prince Rupert
# Processing Record 19 | Vaini
# Processing Record 20 | Talnakh
# Processing Record 21 | Languyan
# Processing Record 22 | Avarua
# Processing Record 23 | Ixtapa
# Processing Record 24 | Qandahar
# The requested city of: Qandahar was not found. Skipping...
# Processing Record 25 | Kodiak
# Processing Record 26 | Havoysund
# Processing Record 27 | Saurimo
# Processing Record 28 | Burnie
# Processing Record 29 | New Norfolk
# Processing Record 30 | Lakes Entrance
# Processing Record 31 | Kondinskoye
# Processing Record 32 | Bredasdorp
# Processing Record 33 | East London
# Processing Record 34 | Hithadhoo
# Processing Record 35 | Puerto Penasco
# Processing Record 36 | Ponta Do Sol
# Processing Record 37 | Faanui
# Processing Record 38 | Priargunsk
# Processing Record 39 | Asosa
# Processing Record 40 | Kerema
# Processing Record 41 | Saldanha
# Processing Record 42 | Barentsburg
# The requested city of: Barentsburg was not found. Skipping...
# Processing Record 43 | Aketi
# Processing Record 44 | Tura
# Processing Record 45 | Anadyr
# Processing Record 46 | Puerto Ayora
# Processing Record 47 | Codrington
# Processing Record 48 | Khani
# Processing Record 49 | Ravar
# Processing Record 50 | Charters Towers
# Processing Record 1 | Fort Smith
# Processing Record 2 | Sentyabrskiy
# The requested city of: Sentyabrskiy was not found. Skipping...
# Processing Record 3 | Fortuna
# Processing Record 4 | Havre-Saint-Pierre
# Processing Record 5 | Shestakovo
# Processing Record 6 | Sindor
# Processing Record 7 | Sal Rei
# Processing Record 8 | Ilhabela
# Processing Record 9 | Belaya Gora
# Processing Record 10 | Laguna
# Processing Record 11 | Sturgeon Falls
# Processing Record 12 | Leningradskiy
# Processing Record 13 | Mount Gambier
# Processing Record 14 | Kieta
# Processing Record 15 | Macaboboni
# The requested city of: Macaboboni was not found. Skipping...
# Processing Record 16 | Nikolskoye
# Processing Record 17 | Xuanhua
# Processing Record 18 | Airai
# Processing Record 19 | Lerwick
# Processing Record 20 | Vaitupu
# The requested city of: Vaitupu was not found. Skipping...
# Processing Record 21 | Provideniya
# Processing Record 22 | Hermanus
# Processing Record 23 | Yar-Sale
# Processing Record 24 | Georgetown
# Processing Record 25 | Victoria
# Processing Record 26 | Bambous Virieux
# Processing Record 27 | Kudahuvadhoo
# Processing Record 28 | Goderich
# Processing Record 29 | Leh
# Processing Record 30 | Dunedin
# Processing Record 31 | Cerrito
# Processing Record 32 | Lorengau
# Processing Record 33 | Gorno-Chuyskiy
# The requested city of: Gorno-Chuyskiy was not found. Skipping...
# Processing Record 34 | Lufilufi
# Processing Record 35 | Katsuura
# Processing Record 36 | Monte Aprazivel
# Processing Record 37 | Marcona
# The requested city of: Marcona was not found. Skipping...
# Processing Record 38 | Carutapera
# Processing Record 39 | Lalmohan
# Processing Record 40 | Matara
# Processing Record 41 | Dikson
# Processing Record 42 | Hilo
# Processing Record 43 | Arraial Do Cabo
# Processing Record 44 | Alcudia
# Processing Record 45 | Cheremukhovo
# Processing Record 46 | Sur
# Processing Record 47 | Buchanan
# Processing Record 48 | Port Hedland
# Processing Record 49 | Pavlovsk
# Processing Record 50 | Tak
# Processing Record 1 | Cidreira
# Processing Record 2 | Olinda
# Processing Record 3 | Baruun-Urt
# Processing Record 4 | Ilulissat
# Processing Record 5 | Eyl
# Processing Record 6 | Praia Da Vitoria
# Processing Record 7 | Garowe
# Processing Record 8 | Narsaq
# Processing Record 9 | Karsun
# Processing Record 10 | Mezen
# Processing Record 11 | Saint-Francois
# Processing Record 12 | Constitucion
# Processing Record 13 | Sao Filipe
# Processing Record 14 | Rizhao
# Processing Record 15 | Isangel
# Processing Record 16 | High Rock
# Processing Record 17 | Nizhneyansk
# The requested city of: Nizhneyansk was not found. Skipping...
# Processing Record 18 | Kumluca
# Processing Record 19 | Ganzhou
# Processing Record 20 | Malwan
# The requested city of: Malwan was not found. Skipping...
# Processing Record 21 | Port Alfred
# Processing Record 22 | Kathu
# Processing Record 23 | Norman Wells
# Processing Record 24 | Umzimvubu
# The requested city of: Umzimvubu was not found. Skipping...
# Processing Record 25 | Chuy
# Processing Record 26 | Amberley
# Processing Record 27 | Klaksvik
# Processing Record 28 | Lasa
# Processing Record 29 | Saleaula
# The requested city of: Saleaula was not found. Skipping...
# Processing Record 30 | Athens
# Processing Record 31 | Vao
# Processing Record 32 | Egvekinot
# Processing Record 33 | Bandarbeyla
# Processing Record 34 | Severo-Kurilsk
# Processing Record 35 | Cabo San Lucas
# Processing Record 36 | Illoqqortoormiut
# The requested city of: Illoqqortoormiut was not found. Skipping...
# Processing Record 37 | Carnarvon
# Processing Record 38 | Vardo
# Processing Record 39 | Grenville
# Processing Record 40 | Tessalit
# Processing Record 41 | Kununurra
# Processing Record 42 | Port Macquarie
# Processing Record 43 | Sibu
# Processing Record 44 | San Cristobal
# Processing Record 45 | Sabang
# Processing Record 46 | Garmsar
# Processing Record 47 | Tuatapere
# Processing Record 48 | Amderma
# The requested city of: Amderma was not found. Skipping...
# Processing Record 49 | Kargasok
# Processing Record 50 | Ust-Uda
# Processing Record 1 | Pidhaytsi
# Processing Record 2 | Agua Dulce
# Processing Record 3 | Gat
# Processing Record 4 | Ulladulla
# Processing Record 5 | Saint George
# Processing Record 6 | Santiago De Puringla
# Processing Record 7 | Zanjan
# Processing Record 8 | Krasnoselkup
# The requested city of: Krasnoselkup was not found. Skipping...
# Processing Record 9 | Pacific Grove
# Processing Record 10 | Sola
# Processing Record 11 | Lima
# Processing Record 12 | Krasnoarmeysk
# Processing Record 13 | San Juan
# Processing Record 14 | Bayir
# Processing Record 15 | Ossora
# Processing Record 16 | Orel
# Processing Record 17 | Luderitz
# Processing Record 18 | Kindu
# Processing Record 19 | Clyde River
# Processing Record 20 | Omboue
# Processing Record 21 | Iqaluit
# Processing Record 22 | Sorong
# Processing Record 23 | Port Elizabeth
# Processing Record 24 | Moundsville
# Processing Record 25 | Luganville
# Processing Record 26 | Cap Malheureux
# Processing Record 27 | Mahajanga
# Processing Record 28 | Tual
# Processing Record 29 | Benjamin Aceval
# Processing Record 30 | Bengkulu
# The requested city of: Bengkulu was not found. Skipping...
# Processing Record 31 | Ambon
# Processing Record 32 | Flinders
# Processing Record 33 | Verkhnevilyuysk
# Processing Record 34 | Armacao Dos Buzios
# The requested city of: Armacao Dos Buzios was not found. Skipping...
# Processing Record 35 | Imeni Zhelyabova
# Processing Record 36 | Rocha
# Processing Record 37 | Raahe
# Processing Record 38 | Shubarkuduk
# Processing Record 39 | Roald
# Processing Record 40 | Ponoka
# Processing Record 41 | Ust-Kuyga
# Processing Record 42 | Smithers
# Processing Record 43 | Bathsheba
# Processing Record 44 | Lata
# Processing Record 45 | Kot Putli
# The requested city of: Kot Putli was not found. Skipping...
# Processing Record 46 | Quatre Cocos
# Processing Record 47 | Wajir
# Processing Record 48 | Hasaki
# Processing Record 49 | Middelburg
# Processing Record 50 | Saint-Augustin
# Processing Record 1 | Champerico
# Processing Record 2 | Catuday
# Processing Record 3 | San Patricio
# Processing Record 4 | Loukhi
# Processing Record 5 | Umm Ruwabah
# The requested city of: Umm Ruwabah was not found. Skipping...
# Processing Record 6 | Ulaanbaatar
# Processing Record 7 | Harper
# Processing Record 8 | Yellowknife
# Processing Record 9 | Salem
# Processing Record 10 | Attawapiskat
# The requested city of: Attawapiskat was not found. Skipping...
# Processing Record 11 | Kropotkin
# Processing Record 12 | Chara
# Processing Record 13 | Mahebourg
# Processing Record 14 | Tenamaxtlan
# Processing Record 15 | Nassau
# Processing Record 16 | Gayeri
# Processing Record 17 | Botucatu
# Processing Record 18 | Chongwe
# Processing Record 19 | Cortez
# Processing Record 20 | Dongsheng
# Processing Record 21 | Mahadday Weyne
# The requested city of: Mahadday Weyne was not found. Skipping...
# Processing Record 22 | Aksu
# Processing Record 23 | Turayf
# Processing Record 24 | Auki
# Processing Record 25 | Udachnyy
# Processing Record 26 | Batagay
# Processing Record 27 | Karratha
# Processing Record 28 | Itoman
# Processing Record 29 | Mao
# Processing Record 30 | Nosy Varika
# Processing Record 31 | Marsabit
# Processing Record 32 | Yakeshi
# Processing Record 33 | Kavieng
# Processing Record 34 | Gloggnitz
# Processing Record 35 | Mehamn
# Processing Record 36 | Najran
# Processing Record 37 | Dholka
# Processing Record 38 | Palembang
# Processing Record 39 | Vila Velha
# Processing Record 40 | Bethel
# Processing Record 41 | El Faiyum
# The requested city of: El Faiyum was not found. Skipping...
# Processing Record 42 | Camacha
# Processing Record 43 | Aksarka
# Processing Record 44 | Luebo
# Processing Record 45 | Maragogi
# Processing Record 46 | Hami
# Processing Record 47 | Tocopilla
# Processing Record 48 | Shaunavon
# Processing Record 49 | Hamilton
# Processing Record 50 | Da Lat
# Processing Record 1 | Chukhloma
# Processing Record 2 | Riohacha
# Processing Record 3 | Nsanje
# Processing Record 4 | Abu Kamal
# Processing Record 5 | Creston
# Processing Record 6 | Oskarshamn
# Processing Record 7 | Unye
# The requested city of: Unye was not found. Skipping...
# Processing Record 8 | Coahuayana
# Processing Record 9 | Sabya
# Processing Record 10 | Xichang
# Processing Record 11 | Avera
# Processing Record 12 | Saint-Gaudens
# Processing Record 13 | Suntar
# Processing Record 14 | Khalkhal
# Processing Record 15 | Kavaratti
# Processing Record 16 | Paamiut
# Processing Record 17 | Tambul
# The requested city of: Tambul was not found. Skipping...
# Processing Record 18 | Coyuca
# The requested city of: Coyuca was not found. Skipping...
# Processing Record 19 | Amahai
# Processing Record 20 | Antofagasta
# Processing Record 21 | Zhigansk
# Processing Record 22 | Teya
# Processing Record 23 | Nizhniy Tsasuchey
# Processing Record 24 | Noshiro
# Processing Record 25 | Hashtrud
# Processing Record 26 | Ruatoria
# The requested city of: Ruatoria was not found. Skipping...
# Processing Record 27 | El Alto
# Processing Record 28 | Krasnogorskiy
# Processing Record 29 | Halalo
# The requested city of: Halalo was not found. Skipping...
# Processing Record 30 | Haines Junction
# Processing Record 31 | Kruisfontein
# Processing Record 32 | Benoy
# Processing Record 33 | Claremore
# Processing Record 34 | Canico
# Processing Record 35 | Januaria
# The requested city of: Januaria was not found. Skipping...
# Processing Record 36 | Slobidka
# Processing Record 37 | Tevaitoa
# Processing Record 38 | Itaqui
# Processing Record 39 | Vostok
# Processing Record 40 | Yerofey Pavlovich
# Processing Record 41 | Padang
# Processing Record 42 | Henties Bay
# Processing Record 43 | Kungurtug
# Processing Record 44 | Kuytun
# Processing Record 45 | San Rafael
# Processing Record 46 | Enumclaw
# Processing Record 47 | Hassleholm
# Processing Record 48 | Wasilla
# Processing Record 49 | Banyo
# Processing Record 50 | Maykor
# Processing Record 1 | Los Llanos De Aridane
# Processing Record 2 | Mar Del Plata
# Processing Record 3 | Guilin
# Processing Record 4 | Gao
# Processing Record 5 | Zastron
# Processing Record 6 | Talawdi
# The requested city of: Talawdi was not found. Skipping...
# Processing Record 7 | Waingapu
# Processing Record 8 | Thinadhoo
# Processing Record 9 | Geraldton
# Processing Record 10 | Tambovka
# Processing Record 11 | Satitoa
# The requested city of: Satitoa was not found. Skipping...
# Processing Record 12 | Tanout
# Processing Record 13 | Aksay
# Processing Record 14 | Sorland
# Processing Record 15 | Sisimiut
# Processing Record 16 | Arandis
# Processing Record 17 | Tagusao
# Processing Record 18 | Zhanaozen
# Processing Record 19 | Miraflores
# Processing Record 20 | Kankakee
# Processing Record 21 | Tilichiki
# Processing Record 22 | Byron Bay
# Processing Record 23 | Gurskoye
# The requested city of: Gurskoye was not found. Skipping...
# Processing Record 24 | Cedar City
# Processing Record 25 | Kamina
# Processing Record 26 | Husavik
# Processing Record 27 | Tallahassee
# Processing Record 28 | Dali
# Processing Record 29 | Kissidougou
# Processing Record 30 | Morros
# Processing Record 31 | Phan Thiet
# Processing Record 32 | Areia Branca
# Processing Record 33 | Khash
# Processing Record 34 | Westport
# Processing Record 35 | Andselv
# The requested city of: Andselv was not found. Skipping...
# Processing Record 36 | Ulaangom
# Processing Record 37 | Kadykchan
# The requested city of: Kadykchan was not found. Skipping...
# Processing Record 38 | Alta Floresta
# Processing Record 39 | Mlonggo
# Processing Record 40 | Villa Oliva
# The requested city of: Villa Oliva was not found. Skipping...
# Processing Record 41 | Necochea
# Processing Record 42 | Coleraine
# Processing Record 43 | Fairbanks
# Processing Record 44 | Providencia
# Processing Record 45 | Craig
# Processing Record 46 | Meyungs
# The requested city of: Meyungs was not found. Skipping...
# Processing Record 47 | Shangrao
# Processing Record 48 | Caronport
# Processing Record 49 | Chapais
# Processing Record 50 | Soyo
# Processing Record 1 | Jumla
# Processing Record 2 | Santiago De Cao
# Processing Record 3 | Guerrero Negro
# Processing Record 4 | Safwah
# The requested city of: Safwah was not found. Skipping...
# Processing Record 5 | Zatoka
# Processing Record 6 | Ozernovskiy
# Processing Record 7 | Bosaso
# Processing Record 8 | Uyuni
# Processing Record 9 | Grand Gaube
# Processing Record 10 | Ouro Preto Do Oeste
# Processing Record 11 | Mackay
# Processing Record 12 | Sorvag
# The requested city of: Sorvag was not found. Skipping...
# Processing Record 13 | Nabire
# Processing Record 14 | Loa Janan
# Processing Record 15 | Meulaboh
# Processing Record 16 | Gamba
# Processing Record 17 | Port Blair
# Processing Record 18 | Qaqortoq
# Processing Record 19 | Huarmey
# Processing Record 20 | Calinesti
# Processing Record 21 | Sumter
# Processing Record 22 | Longyearbyen
# Processing Record 23 | Diego De Almagro
# Processing Record 24 | Slave Lake
# Processing Record 25 | Abha
# Processing Record 26 | Kiama
# Processing Record 27 | Pangnirtung
# Processing Record 28 | Searcy
# Processing Record 29 | Jiuquan
# Processing Record 30 | Taltal
# Processing Record 31 | Krasnogorodsk
# Processing Record 32 | Xuddur
# Processing Record 33 | Saint-Pierre
# Processing Record 34 | Nome
# Processing Record 35 | Kamenskoye
# The requested city of: Kamenskoye was not found. Skipping...
# Processing Record 36 | Ushumun
# Processing Record 37 | Sawakin
# Processing Record 38 | Vuktyl
# Processing Record 39 | Victor Harbor
# Processing Record 40 | Lompoc
# Processing Record 41 | Srednekolymsk
# Processing Record 42 | Samusu
# The requested city of: Samusu was not found. Skipping...
# Processing Record 43 | Salalah
# Processing Record 44 | Andenes
# The requested city of: Andenes was not found. Skipping...
# Processing Record 45 | Wuda
# Processing Record 46 | Kanker
# Processing Record 47 | Maloy
# Processing Record 48 | Saint Anthony
# Processing Record 49 | Pevek
# Processing Record 50 | Masvingo
# Processing Record 1 | Sayyan
# Processing Record 2 | Roma
# Processing Record 3 | Ancud
# Processing Record 4 | York
# Processing Record 5 | Rungata
# The requested city of: Rungata was not found. Skipping...
# Processing Record 6 | Finschhafen
# Processing Record 7 | Tsihombe
# The requested city of: Tsihombe was not found. Skipping...
# Processing Record 8 | Torbay
# Processing Record 9 | Carauari
# Processing Record 10 | Neuquen
# Processing Record 11 | Rawson
# Processing Record 12 | Pahrump
# Processing Record 13 | Sungaipenuh
# Processing Record 14 | Macau
# Processing Record 15 | North Bend
# Processing Record 16 | Mercedes
# Processing Record 17 | Denpasar
# Processing Record 18 | Dubbo
# Processing Record 19 | Faya
# Processing Record 20 | Berlevag
# Processing Record 21 | Hauknes
# Processing Record 22 | Sosua
# Processing Record 23 | Portland
# Processing Record 24 | Raiganj
# Processing Record 25 | Grindavik
# Processing Record 26 | Shelburne
# Processing Record 27 | Poum
# Processing Record 28 | Myitkyina
# Processing Record 29 | Zonguldak
# Processing Record 30 | Coquimbo
# Processing Record 31 | Bambanglipuro
# Processing Record 32 | Sao Joao Da Barra
# Processing Record 33 | Kutum
# Processing Record 34 | Pishva
# Processing Record 35 | Buala
# Processing Record 36 | Aklavik
# Processing Record 37 | Nouakchott
# Processing Record 38 | Tiksi
# Processing Record 39 | Pampa
# Processing Record 40 | Fare
# Processing Record 41 | Zermatt
# Processing Record 42 | Xiongshi
# The requested city of: Xiongshi was not found. Skipping...
# Processing Record 43 | College
# Processing Record 44 | Kaili
# Processing Record 45 | Poindimie
# Processing Record 46 | Winneba
# Processing Record 47 | Karlshamn
# Processing Record 48 | Palabuhanratu
# The requested city of: Palabuhanratu was not found. Skipping...
# Processing Record 49 | Thilogne
# The requested city of: Thilogne was not found. Skipping...
# Processing Record 50 | High Level
# Processing Record 1 | Jacareacanga
# Processing Record 2 | Alice Town
# Processing Record 3 | Maningrida
# Processing Record 4 | Imbituba
# Processing Record 5 | Okhotsk
# Processing Record 6 | Odweyne
# The requested city of: Odweyne was not found. Skipping...
# Processing Record 7 | Ixchiguan
# Processing Record 8 | Singaparna
# Processing Record 9 | Shingu
# Processing Record 10 | Mattru
# Processing Record 11 | Sorgun
# Processing Record 12 | Kangaba
# Processing Record 13 | Makung
# The requested city of: Makung was not found. Skipping...
# Processing Record 14 | Magaria
# Processing Record 15 | Kijang
# Processing Record 16 | Qasigiannguit
# Processing Record 17 | Manadhoo
# Processing Record 18 | Oshikango
# Processing Record 19 | Labuan
# Processing Record 20 | Calama
# Processing Record 21 | Acajutla
# Processing Record 22 | Iracoubo
# Processing Record 23 | Wanlaweyn
# Processing Record 24 | Yialos
# The requested city of: Yialos was not found. Skipping...
# Processing Record 25 | Unity
# Processing Record 26 | Tumannyy
# The requested city of: Tumannyy was not found. Skipping...
# Processing Record 27 | Bur Gabo
# The requested city of: Bur Gabo was not found. Skipping...
# Processing Record 28 | Bocas Del Toro
# Processing Record 29 | Pishin
# Processing Record 30 | Ola
# Processing Record 31 | Preston
# Processing Record 32 | Nyurba
# Processing Record 33 | Novyye Burasy
# Processing Record 34 | Petropavlovsk-Kamchatskiy
# Processing Record 35 | Muisne
# Processing Record 36 | Grand River South East
# The requested city of: Grand River South East was not found. Skipping...
# Processing Record 37 | Daru
# Processing Record 38 | Nelson Bay
# Processing Record 39 | Itapirapua
# Processing Record 40 | Greensboro
# Processing Record 41 | Palmer
# Processing Record 42 | Azimur
# The requested city of: Azimur was not found. Skipping...
# Processing Record 43 | Lewisporte
# Processing Record 44 | Ocean City
# Processing Record 45 | Zverinogolovskoye
# Processing Record 46 | Kisangani
# Processing Record 47 | Sterling
# Processing Record 48 | Abu Dhabi
# Processing Record 49 | Rena
# Processing Record 50 | Zhob
# Processing Record 1 | Broome
# Processing Record 2 | Nakapiripirit
# Processing Record 3 | Vanimo
# Processing Record 4 | Pimentel
# Processing Record 5 | Ipu
# Processing Record 6 | Santa Catarina De Tepehuanes
# Processing Record 7 | Chamba
# Processing Record 8 | Pisco
# Processing Record 9 | Char Bhadrasan
# Processing Record 10 | Tweed
# Processing Record 11 | San Ramon
# Processing Record 12 | Bargal
# The requested city of: Bargal was not found. Skipping...
# Processing Record 13 | Dzerzhinskoye
# Processing Record 14 | Arlit
# Processing Record 15 | Yei
# The requested city of: Yei was not found. Skipping...
# Processing Record 16 | Ksenyevka
# The requested city of: Ksenyevka was not found. Skipping...
# Processing Record 17 | Puyo
# Processing Record 18 | Kahului
# Processing Record 19 | Nanakuli
# Processing Record 20 | Caravelas
# Processing Record 21 | Manitouwadge
# Processing Record 22 | Tecoanapa
# Processing Record 23 | Piranhas
# Processing Record 24 | Antalaha
# Processing Record 25 | Tartki
# The requested city of: Tartki was not found. Skipping...
# Processing Record 26 | Inndyr
# Processing Record 27 | Kaoma
# Processing Record 28 | Whitianga
# Processing Record 29 | Wewak
# Processing Record 30 | Kijini
# Processing Record 31 | Ijevan
# Processing Record 32 | Bontang
# Processing Record 33 | George
# Processing Record 34 | Negombo
# Processing Record 35 | Udaipur
# Processing Record 36 | Majene
# Processing Record 37 | Poitiers
# Processing Record 38 | Kousseri
# The requested city of: Kousseri was not found. Skipping...
# Processing Record 39 | Tyrma
# Processing Record 40 | Dawei
# Processing Record 41 | Marshfield
# Processing Record 42 | Santa Isabel Do Rio Negro
# Processing Record 43 | Plettenberg Bay
# Processing Record 44 | Altay
# Processing Record 45 | Nenjiang
# Processing Record 46 | Mount Isa
# Processing Record 47 | Jijiga
# Processing Record 48 | Bafra
# Processing Record 49 | Bella Vista
# Processing Record 50 | Te Anau
# Processing Record 1 | Porto Novo
# Processing Record 2 | Yermakovskoye
# Processing Record 3 | Elizabeth City
# Processing Record 4 | Hollins
# Processing Record 5 | Agadez
# Processing Record 6 | Miandrivazo
# Processing Record 7 | Omsukchan
# Processing Record 8 | Isla Mujeres
# Processing Record 9 | Siteki
# Processing Record 10 | Kostomuksha
# Processing Record 11 | Starosubkhangulovo
# Processing Record 12 | Bikaner
# Processing Record 13 | Oranjemund
# Processing Record 14 | Broken Hill
# Processing Record 15 | Cerro Largo
# Processing Record 16 | Ndiekro
# The requested city of: Ndiekro was not found. Skipping...
# Processing Record 17 | Nishihara

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
len(city_name) --549
len(humidity) --549
len(wind_speed ) --549

# VALUES ZIP BELOW WAS USED SUCCESSFULLY FOR CONVERTING THE LISTS TO A ZIP TO A CSV FILE (LOOKED IN PYTHON DAY 2 @ UDEMY ACTIVITY)
city_data_zip = zip(city_name, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed)

# CONVERT TO CSV FILE

with open("output_data/cities.csv", 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp (Celsius)', 'Wind Speed'])
    writer.writerows(city_data_zip)
    
cities_data=pd.read_csv("output_data/cities.csv")
cities_data.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Esperance          90      AU  1570232169       100 -33.86  121.89
# 1         Rikitea          86      PF  1570231794        79 -23.12 -134.97
# 2       Dovolnoye          72      RU  1570232257        91  54.50   79.67
# 3           Muros           0      ES  1570232258       100  42.77   -9.06
# 4  Ribeira Grande         100      PT  1570232042        77  38.52  -28.70
#
#    Max Temp (Celsius)  Wind Speed
# 0               14.00        8.70
# 1               21.24        9.70
# 2                8.31        2.84
# 3               14.44        0.85
# 4               20.67        5.17

# %%
print(cities_data.head())
cities_data.count()
#cities_data['Date'].max()
cities_data['Date']=pd.to_datetime(cities_data['Date'], unit='s')
cities_data['Date']
# Out:
#              City  Cloudiness Country                Date  Humidity    Lat  \
# 0       Esperance          90      AU 2019-10-04 23:36:09       100 -33.86
# 1         Rikitea          86      PF 2019-10-04 23:29:54        79 -23.12
# 2       Dovolnoye          72      RU 2019-10-04 23:37:37        91  54.50
# 3           Muros           0      ES 2019-10-04 23:37:38       100  42.77
# 4  Ribeira Grande         100      PT 2019-10-04 23:34:02        77  38.52
#
#       Lng  Max Temp (Celsius)  Wind Speed
# 0  121.89               14.00        8.70
# 1 -134.97               21.24        9.70
# 2   79.67                8.31        2.84
# 3   -9.06               14.44        0.85
# 4  -28.70               20.67        5.17
# 0     2019-10-04 23:36:09
# 1     2019-10-04 23:29:54
# 2     2019-10-04 23:37:37
# 3     2019-10-04 23:37:38
# 4     2019-10-04 23:34:02
#               ...
# 548   2019-10-04 23:40:32
# 549   2019-10-04 23:40:33
# 550   2019-10-04 23:40:33
# 551   2019-10-04 23:40:33
# 552   2019-10-04 23:40:34
# Name: Date, Length: 553, dtype: datetime64[ns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Plotting the scatter plot for Latitude versus Temperature in Celsius
plt.figure(1)
plt.scatter(cities_data['Lat'], cities_data['Max Temp (Celsius)'], marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Max Temperature (10/04/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
plt.show()

#Save the figure
plt.savefig('./citylatitude_vs_maxtemp.png')

#Scatter Plot shows the gradual increase in temperature as the distance from Equator (0 Latitude) decreases .
#Regions closer to Earth’s equator experience higher temperatures than regions near the North and South poles.
#Highest temperatures occur beween 0 and +-40 Latitude.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Plotting the scatter plot for Latitude versus Humidity
plt.figure(1)
plt.scatter(cities_data['Lat'], cities_data['Humidity'], marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Humidity (10/04/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(-10,110,10)
plt.grid()
plt.show()

#Save the figure
plt.savefig('./citylatitude_vs_Humidity.png')

#Scatter Plot shows that humidity at this time of year does not really vary with Latitude.Th plot shows a Humidity percent between
#60 to 100% for all Latitude.Latitude 40-70 (Northern Hemisphere) seems to have higher percentage of Humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plotting the scatter plot for Latitude versus Cloudiness
plt.figure(1)
plt.scatter(cities_data['Lat'], cities_data['Cloudiness'], marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Cloudiness (10/04/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

#Save the figure
plt.savefig('./citylatitude_vs_Cloudiness.png')

#Scatter Plot does not really show any pattern for Cloudiness.Cities on same Latitude have Cloudiness% varying from 0 to 100%
# indicating that there are other factors in play

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Plotting the scatter plot for Latitude versus Wind Speed
plt.figure(1)
plt.scatter(cities_data['Lat'], cities_data['Wind Speed'], marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Wind Speed (10/04/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()

#Save the figure
plt.savefig('./citylatitude_vs_WindSpeed.png')

#Scatter Plot shows Wind speed upto 10mph for all Latitude. Wind speed is increasing towards higher Latitude especially 
#in Northern Hemisphere with speeds reaching upto 20 mph for some cities.
